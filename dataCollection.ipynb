# %%
import requests

# %%
URL = "http://localhost:8888/lab/tree/dataCollection.ipynb"

res = requests.get(URL)

# %%
res
# Out:
# <Response [200]>

# %%
URL2 = "https://stephen-king-api.onrender.com/api/books"
res = requests.get(URL2)
json_data2 = res.json()

# %%
import pandas as pd
df = pd.json_normalize(json_data2["data"])

# %%
df
# Out:
#     id  Year          Title         handle        Publisher  \
# 0    1  1974         Carrie         carrie        Doubleday
# 1    2  1975    Salem's Lot    salem-s-lot        Doubleday
# 2    3  1977    The Shining    the-shining        Doubleday
# 3    4  1977           Rage           rage     Signet Books
# 4    5  1978      The Stand      the-stand        Doubleday
# ..  ..   ...            ...            ...              ...
# 58  59  2018   The Outsider   the-outsider         Scribner
# 59  60  2018      Elevation      elevation         Scribner
# 60  61  2019  The Institute  the-institute         Scribner
# 61  62  2021          Later          later  Hard Case Crime
# 62  63  2021  Billy Summers  billy-summers         Scribner
#
#                  ISBN  Pages  \
# 0   978-0-385-08695-0    199
# 1   978-0-385-00751-1    439
# 2   978-0-385-12167-5    447
# 3   978-0-451-07645-8    211
# 4   978-0-385-12168-2    823
# ..                ...    ...
# 58  978-1-50118-098-9    576
# 59  978-1-98210-231-9    144
# 60  978-1-98211-056-7    576
# 61  978-1-78909-649-1    256
# 62  978-1-982-17361-6    528
#
#                                                 Notes  \
# 0                                                  []
# 1             [Nominee, World Fantasy Award, 1976[2]]
# 2   [Runner-up (4th place), Locus Award for Best F...
# 3         [Published under pseudonym Richard Bachman]
# 4   [Nominee, World Fantasy Award, 1979, Runner-up...
# ..                                                ...
# 58  [First novel in the Holly Gibney Series, Runne...
# 59                                                 []
# 60  [Nominee, British Fantasy Award's August Derle...
# 61                                                 []
# 62                                                 []
#
#                   created_at  \
# 0   2023-11-13T23:48:47.848Z
# 1   2023-11-13T23:48:48.098Z
# 2   2023-11-13T23:48:48.219Z
# 3   2023-11-13T23:48:48.339Z
# 4   2023-11-13T23:48:48.477Z
# ..                       ...
# 58  2023-11-13T23:48:55.165Z
# 59  2023-11-13T23:48:55.291Z
# 60  2023-11-13T23:48:55.457Z
# 61  2023-11-13T23:48:55.579Z
# 62  2023-11-13T23:48:55.753Z
#
#                                              villains
# 0   [{'name': 'Tina Blake', 'url': 'https://stephe...
# 1   [{'name': 'Kurt Barlow', 'url': 'https://steph...
# 2   [{'name': 'Horace M. Derwent', 'url': 'https:/...
# 3                                                  []
# 4   [{'name': 'Donald Merwin Elbert', 'url': 'http...
# ..                                                ...
# 58  [{'name': 'The Outsider (Creature)', 'url': 'h...
# 59                                                 []
# 60  [{'name': 'Gladys Hickson', 'url': 'https://st...
# 61                                                 []
# 62                                                 []
#
# [63 rows x 10 columns]

# %%
df = df[['id', 'Title', 'Year', 'ISBN']];

# %%
df
# Out:
#     id          Title  Year               ISBN
# 0    1         Carrie  1974  978-0-385-08695-0
# 1    2    Salem's Lot  1975  978-0-385-00751-1
# 2    3    The Shining  1977  978-0-385-12167-5
# 3    4           Rage  1977  978-0-451-07645-8
# 4    5      The Stand  1978  978-0-385-12168-2
# ..  ..            ...   ...                ...
# 58  59   The Outsider  2018  978-1-50118-098-9
# 59  60      Elevation  2018  978-1-98210-231-9
# 60  61  The Institute  2019  978-1-98211-056-7
# 61  62          Later  2021  978-1-78909-649-1
# 62  63  Billy Summers  2021  978-1-982-17361-6
#
# [63 rows x 4 columns]

# %%
URL2 = "https://cdn.jsdelivr.net/gh/fawazahmed0/quran-api@1/editions.json"
req2 = requests.get(URL2);
json_data2 = req2.json();

# %%
df = pd.json_normalize(list(json_data2.values()))

# %%
df
# Out:
#                                                   0   \
# 0  {'id': 1, 'Year': 1974, 'Title': 'Carrie', 'ha...
#
#                                                   1   \
# 0  {'id': 2, 'Year': 1975, 'Title': 'Salem's Lot'...
#
#                                                   2   \
# 0  {'id': 3, 'Year': 1977, 'Title': 'The Shining'...
#
#                                                   3   \
# 0  {'id': 4, 'Year': 1977, 'Title': 'Rage', 'hand...
#
#                                                   4   \
# 0  {'id': 5, 'Year': 1978, 'Title': 'The Stand', ...
#
#                                                   5   \
# 0  {'id': 6, 'Year': 1979, 'Title': 'The Long Wal...
#
#                                                   6   \
# 0  {'id': 7, 'Year': 1979, 'Title': 'The Dead Zon...
#
#                                                   7   \
# 0  {'id': 8, 'Year': 1980, 'Title': 'Firestarter'...
#
#                                                   8   \
# 0  {'id': 9, 'Year': 1981, 'Title': 'Roadwork', '...
#
#                                                   9   ...  \
# 0  {'id': 10, 'Year': 1981, 'Title': 'Cujo', 'han...  ...
#
#                                                   53  \
# 0  {'id': 54, 'Year': 2014, 'Title': 'Revival', '...
#
#                                                   54  \
# 0  {'id': 55, 'Year': 2015, 'Title': 'Finders Kee...
#
#                                                   55  \
# 0  {'id': 56, 'Year': 2016, 'Title': 'End of Watc...
#
#                                                   56  \
# 0  {'id': 57, 'Year': 2017, 'Title': 'Gwendy's Bu...
#
#                                                   57  \
# 0  {'id': 58, 'Year': 2017, 'Title': 'Sleeping Be...
#
#                                                   58  \
# 0  {'id': 59, 'Year': 2018, 'Title': 'The Outside...
#
#                                                   59  \
# 0  {'id': 60, 'Year': 2018, 'Title': 'Elevation',...
#
#                                                   60  \
# 0  {'id': 61, 'Year': 2019, 'Title': 'The Institu...
#
#                                                   61  \
# 0  {'id': 62, 'Year': 2021, 'Title': 'Later', 'ha...
#
#                                                   62
# 0  {'id': 63, 'Year': 2021, 'Title': 'Billy Summe...
#
# [1 rows x 63 columns]

# %%
URL = "https://www.scrapethissite.com/pages/simple/"
res = requests.get(URL)

# %%
print(res.status_code)
# Out:
# 200

# %%
# if res.status_code == 200:
#     print(res.text);

with open("scraped_data/data1.html", "w", encoding="utf-8") as f:
    f.write(res.text)

# %%
# Beautifulsoup
# pip install beautifulsoup4

from bs4 import BeautifulSoup

# %%
with open("scraped_data/data1.html", "r") as f:
    html_content = f.read();

soup = BeautifulSoup(html_content, "lxml")

# %%
all_h3 = soup.find_all("h3")

all_countries = []

for h3 in all_h3:
    name = h3.get_text(strip=True)
    population = h3.find_next("div").select("span.country-population")[0].get_text(strip=True)

    all_countries.append([name, population])

# %%
all_countries
# Out:
# [['Andorra', '84000'],
#  ['United Arab Emirates', '4975593'],
#  ['Afghanistan', '29121286'],
#  ['Antigua and Barbuda', '86754'],
#  ['Anguilla', '13254'],
#  ['Albania', '2986952'],
#  ['Armenia', '2968000'],
#  ['Angola', '13068161'],
#  ['Antarctica', '0'],
#  ['Argentina', '41343201'],
#  ['American Samoa', '57881'],
#  ['Austria', '8205000'],
#  ['Australia', '21515754'],
#  ['Aruba', '71566'],
#  ['Ã…land', '26711'],
#  ['Azerbaijan', '8303512'],
#  ['Bosnia and Herzegovina', '4590000'],
#  ['Barbados', '285653'],
#  ['Bangladesh', '156118464'],
#  ['Belgium', '10403000'],
#  ['Burkina Faso', '16241811'],
#  ['Bulgaria', '7148785'],
#  ['Bahrain', '738004'],
#  ['Burundi', '9863117'],
#  ['Benin', '9056010'],
#  ['Saint BarthÃ©lemy', '8450'],
#  ['Bermuda', '65365'],
#  ['Brunei', '395027'],
#  ['Bolivia', '9947418'],
#  ['Bonaire', '18012'],
#  ['Brazil', '201103330'],
#  ['Bahamas', '301790'],
#  ['Bhutan', '699847'],
#  ['Bouvet Island', '0'],
#  ['Botswana', '2029307'],
#  ['Belarus', '9685000'],
#  ['Belize', '314522'],
#  ['Canada', '33679000'],
#  ['Cocos [Keeling] Islands', '628'],
#  ['Democratic Republic of the Congo', '70916439'],
#  ['Central African Republic', '4844927'],
#  ['Republic of the Congo', '3039126'],
#  ['Switzerland', '7581000'],
#  ['Ivory Coast', '21058798'],
#  ['Cook Islands', '21388'],
#  ['Chile', '16746491'],
#  ['Cameroon', '19294149'],
#  ['China', '1330044000'],
#  ['Colombia', '47790000'],
#  ['Costa Rica', '4516220'],
#  ['Cuba', '11423000'],
#  ['Cape Verde', '508659'],
#  ['Curacao', '141766'],
#  ['Christmas Island', '1500'],
#  ['Cyprus', '1102677'],
#  ['Czech Republic', '10476000'],
#  ['Germany', '81802257'],
#  ['Djibouti', '740528'],
#  ['Denmark', '5484000'],
#  ['Dominica', '72813'],
#  ['Dominican Republic', '9823821'],
#  ['Algeria', '34586184'],
#  ['Ecuador', '14790608'],
#  ['Estonia', '1291170'],
#  ['Egypt', '80471869'],
#  ['Western Sahara', '273008'],
#  ['Eritrea', '5792984'],
#  ['Spain', '46505963'],
#  ['Ethiopia', '88013491'],
#  ['Finland', '5244000'],
#  ['Fiji', '875983'],
#  ['Falkland Islands', '2638'],
#  ['Micronesia', '107708'],
#  ['Faroe Islands', '48228'],
#  ['France', '64768389'],
#  ['Gabon', '1545255'],
#  ['United Kingdom', '62348447'],
#  ['Grenada', '107818'],
#  ['Georgia', '4630000'],
#  ['French Guiana', '195506'],
#  ['Guernsey', '65228'],
#  ['Ghana', '24339838'],
#  ['Gibraltar', '27884'],
#  ['Greenland', '56375'],
#  ['Gambia', '1593256'],
#  ['Guinea', '10324025'],
#  ['Guadeloupe', '443000'],
#  ['Equatorial Guinea', '1014999'],
#  ['Greece', '11000000'],
#  ['South Georgia and the South Sandwich Islands', '30'],
#  ['Guatemala', '13550440'],
#  ['Guam', '159358'],
#  ['Guinea-Bissau', '1565126'],
#  ['Guyana', '748486'],
#  ['Hong Kong', '6898686'],
#  ['Heard Island and McDonald Islands', '0'],
#  ['Honduras', '7989415'],
#  ['Croatia', '4491000'],
#  ['Haiti', '9648924'],
#  ['Hungary', '9982000'],
#  ['Indonesia', '242968342'],
#  ['Ireland', '4622917'],
#  ['Israel', '7353985'],
#  ['Isle of Man', '75049'],
#  ['India', '1173108018'],
#  ['British Indian Ocean Territory', '4000'],
#  ['Iraq', '29671605'],
#  ['Iran', '76923300'],
#  ['Iceland', '308910'],
#  ['Italy', '60340328'],
#  ['Jersey', '90812'],
#  ['Jamaica', '2847232'],
#  ['Jordan', '6407085'],
#  ['Japan', '127288000'],
#  ['Kenya', '40046566'],
#  ['Kyrgyzstan', '5776500'],
#  ['Cambodia', '14453680'],
#  ['Kiribati', '92533'],
#  ['Comoros', '773407'],
#  ['Saint Kitts and Nevis', '51134'],
#  ['North Korea', '22912177'],
#  ['South Korea', '48422644'],
#  ['Kuwait', '2789132'],
#  ['Cayman Islands', '44270'],
#  ['Kazakhstan', '15340000'],
#  ['Laos', '6368162'],
#  ['Lebanon', '4125247'],
#  ['Saint Lucia', '160922'],
#  ['Liechtenstein', '35000'],
#  ['Sri Lanka', '21513990'],
#  ['Liberia', '3685076'],
#  ['Lesotho', '1919552'],
#  ['Lithuania', '2944459'],
#  ['Luxembourg', '497538'],
#  ['Latvia', '2217969'],
#  ['Libya', '6461454'],
#  ['Morocco', '31627428'],
#  ['Monaco', '32965'],
#  ['Moldova', '4324000'],
#  ['Montenegro', '666730'],
#  ['Saint Martin', '35925'],
#  ['Madagascar', '21281844'],
#  ['Marshall Islands', '65859'],
#  ['Macedonia', '2062294'],
#  ['Mali', '13796354'],
#  ['Myanmar [Burma]', '53414374'],
#  ['Mongolia', '3086918'],
#  ['Macao', '449198'],
#  ['Northern Mariana Islands', '53883'],
#  ['Martinique', '432900'],
#  ['Mauritania', '3205060'],
#  ['Montserrat', '9341'],
#  ['Malta', '403000'],
#  ['Mauritius', '1294104'],
#  ['Maldives', '395650'],
#  ['Malawi', '15447500'],
#  ['Mexico', '112468855'],
#  ['Malaysia', '28274729'],
#  ['Mozambique', '22061451'],
#  ['Namibia', '2128471'],
#  ['New Caledonia', '216494'],
#  ['Niger', '15878271'],
#  ['Norfolk Island', '1828'],
#  ['Nigeria', '154000000'],
#  ['Nicaragua', '5995928'],
#  ['Netherlands', '16645000'],
#  ['Norway', '5009150'],
#  ['Nepal', '28951852'],
#  ['Nauru', '10065'],
#  ['Niue', '2166'],
#  ['New Zealand', '4252277'],
#  ['Oman', '2967717'],
#  ['Panama', '3410676'],
#  ['Peru', '29907003'],
#  ['French Polynesia', '270485'],
#  ['Papua New Guinea', '6064515'],
#  ['Philippines', '99900177'],
#  ['Pakistan', '184404791'],
#  ['Poland', '38500000'],
#  ['Saint Pierre and Miquelon', '7012'],
#  ['Pitcairn Islands', '46'],
#  ['Puerto Rico', '3916632'],
#  ['Palestine', '3800000'],
#  ['Portugal', '10676000'],
#  ['Palau', '19907'],
#  ['Paraguay', '6375830'],
#  ['Qatar', '840926'],
#  ['RÃ©union', '776948'],
#  ['Romania', '21959278'],
#  ['Serbia', '7344847'],
#  ['Russia', '140702000'],
#  ['Rwanda', '11055976'],
#  ['Saudi Arabia', '25731776'],
#  ['Solomon Islands', '559198'],
#  ['Seychelles', '88340'],
#  ['Sudan', '35000000'],
#  ['Sweden', '9828655'],
#  ['Singapore', '4701069'],
#  ['Saint Helena', '7460'],
#  ['Slovenia', '2007000'],
#  ['Svalbard and Jan Mayen', '2550'],
#  ['Slovakia', '5455000'],
#  ['Sierra Leone', '5245695'],
#  ['San Marino', '31477'],
#  ['Senegal', '12323252'],
#  ['Somalia', '10112453'],
#  ['Suriname', '492829'],
#  ['South Sudan', '8260490'],
#  ['SÃ£o TomÃ© and PrÃ\xadncipe', '175808'],
#  ['El Salvador', '6052064'],
#  ['Sint Maarten', '37429'],
#  ['Syria', '22198110'],
#  ['Swaziland', '1354051'],
#  ['Turks and Caicos Islands', '20556'],
#  ['Chad', '10543464'],
#  ['French Southern Territories', '140'],
#  ['Togo', '6587239'],
#  ['Thailand', '67089500'],
#  ['Tajikistan', '7487489'],
#  ['Tokelau', '1466'],
#  ['East Timor', '1154625'],
#  ['Turkmenistan', '4940916'],
#  ['Tunisia', '10589025'],
#  ['Tonga', '122580'],
#  ['Turkey', '77804122'],
#  ['Trinidad and Tobago', '1228691'],
#  ['Tuvalu', '10472'],
#  ['Taiwan', '22894384'],
#  ['Tanzania', '41892895'],
#  ['Ukraine', '45415596'],
#  ['Uganda', '33398682'],
#  ['U.S. Minor Outlying Islands', '0'],
#  ['United States', '310232863'],
#  ['Uruguay', '3477000'],
#  ['Uzbekistan', '27865738'],
#  ['Vatican City', '921'],
#  ['Saint Vincent and the Grenadines', '104217'],
#  ['Venezuela', '27223228'],
#  ['British Virgin Islands', '21730'],
#  ['U.S. Virgin Islands', '108708'],
#  ['Vietnam', '89571130'],
#  ['Vanuatu', '221552'],
#  ['Wallis and Futuna', '16025'],
#  ['Samoa', '192001'],
#  ['Kosovo', '1800000'],
#  ['Yemen', '23495361'],
#  ['Mayotte', '159042'],
#  ['South Africa', '49000000'],
#  ['Zambia', '13460305'],
#  ['Zimbabwe', '11651858']]

# %%
import pandas as pd
df = pd.DataFrame(all_countries, columns=["Name", "Population"])

# %%
df.to_csv("cleaned_data/data.csv", index=False)
